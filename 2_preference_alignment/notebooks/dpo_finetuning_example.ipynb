# %% [markdown]
# # Preference Alignment with Direct Preference Optimization (DPO)
#
# This notebook will guide you through the process of fine-tuning a language model using Direct Preference Optimization (DPO). We will use the SmolLM2-135M-Instruct model which has already been through a SFT training, so it it compatible with DPO. You can also use the model you trained in [1_instruction_tuning](../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb).
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; color:black'>
#      <h2 style='margin: 0;color:blue'>Exercise: Aligning SmolLM2 with DPOTrainer</h2>
#      <p>Take a dataset from the Hugging Face hub and align a model on it. </p>
#      <p><b>Difficulty Levels</b></p>
#      <p>🐢 Use the `trl-lib/ultrafeedback_binarized` dataset</p>
#      <p>🐕 Try out the `argilla/ultrafeedback-binarized-preferences` dataset</p>
#      <p>🦁 Select a dataset that relates to a real-world use case you’re interested in, or use the model you trained in
#         <a href="../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb">1_instruction_tuning</a></p>
# </div>

# %%
# Install the requirements in Google Colab
# !pip install transformers datasets trl huggingface_hub

# Authenticate to Hugging Face
from dotenv import load_dotenv
from huggingface_hub import login
import os

load_dotenv()

login(token=os.getenv("HF_TOKEN"))
# for convenience you can create an environment variable containing your hub token as HF_TOKEN
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ## Import libraries

# %%
import torch
import os
from transformers import AutoModelForCausalLM, AutoTokenizer
from datasets import load_dataset
from trl import DPOTrainer, DPOConfig

# %% [markdown]
# ## Format dataset

# %%
# Load dataset

# TODO: 🦁🐕 change the dataset to one of your choosing
dataset = load_dataset(path="trl-lib/ultrafeedback_binarized", split="train")

# %%
# TODO: 🐕 If your dataset is not represented as conversation lists, you can use the `process_dataset` function to convert it.

# %% [markdown]
# ## Select the model
#
# We will use the SmolLM2-135M-Instruct model which has already been through a SFT training, so it it compatible with DPO. You can also use the model you trained in [1_instruction_tuning](../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb).
#
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; width:80%; color:black'>
#      <p>🦁 change the model to the path or repo id of the model you trained in <a href="../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb">1_instruction_tuning</a></p>
# </div>

# %%
# TODO: 🦁 change the model to the path or repo id of the model you trained in [1_instruction_tuning](../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb)

model_name = "HuggingFaceTB/SmolLM2-135M-Instruct"

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)

# Model to fine-tune
model = AutoModelForCausalLM.from_pretrained(
    pretrained_model_name_or_path=model_name,
    torch_dtype=torch.float32,
).to(device)
model.config.use_cache = False
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

# Set our name for the finetune to be saved &/ uploaded to
finetune_name = "SmolLM2-FT-DPO"
finetune_tags = ["smol-course", "module_1"]
# Out:
# config.json:   0%|          | 0.00/861 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/269M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.76k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/801k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/655 [00:00<?, ?B/s]

# %% [markdown]
# ## Train model with DPO

# %%
# Training arguments
training_args = DPOConfig(
    # Training batch size per GPU
    per_device_train_batch_size=4,
    # Number of updates steps to accumulate before performing a backward/update pass
    # Effective batch size = per_device_train_batch_size * gradient_accumulation_steps
    gradient_accumulation_steps=4,
    # Saves memory by not storing activations during forward pass
    # Instead recomputes them during backward pass
    gradient_checkpointing=True,
    # Base learning rate for training
    learning_rate=5e-5,
    # Learning rate schedule - 'cosine' gradually decreases LR following cosine curve
    lr_scheduler_type="cosine",
    # Total number of training steps
    max_steps=200,
    # Disables model checkpointing during training
    save_strategy="no",
    # How often to log training metrics
    logging_steps=1,
    # Directory to save model outputs
    output_dir="smol_dpo_output",
    # Number of steps for learning rate warmup
    warmup_steps=100,
    # Use bfloat16 precision for faster training
    bf16=True,
    # Disable wandb/tensorboard logging
    report_to="wandb",
    # Keep all columns in dataset even if not used
    remove_unused_columns=False,
    # Enable MPS (Metal Performance Shaders) for Mac devices
    use_mps_device=device == "mps",
    # Model ID for HuggingFace Hub uploads
    hub_model_id=finetune_name,
    # DPO-specific temperature parameter that controls the strength of the preference model
    # Lower values (like 0.1) make the model more conservative in following preferences
    beta=0.1,
    # Maximum length of the input prompt in tokens
    max_prompt_length=1024,
    # Maximum combined length of prompt + response in tokens
    max_length=1536,
)

# %%
trainer = DPOTrainer(
    # The model to be trained
    model=model,
    # Training configuration from above
    args=training_args,
    # Dataset containing preferred/rejected response pairs
    train_dataset=dataset,
    # Tokenizer for processing inputs
    processing_class=tokenizer,
    # DPO-specific temperature parameter that controls the strength of the preference model
    # Lower values (like 0.1) make the model more conservative in following preferences
    # beta=0.1,
    # Maximum length of the input prompt in tokens
    # max_prompt_length=1024,
    # Maximum combined length of prompt + response in tokens
    # max_length=1536,
)
# Out:
# max_steps is given, it will override any value given in num_train_epochs

# %%
# Train the model
trainer.train()

# Save the model
trainer.save_model(f"./{finetune_name}")

# Save to the huggingface hub if login (HF_TOKEN is set)
if os.getenv("HF_TOKEN"):
    trainer.push_to_hub(tags=finetune_tags)
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# wandb: Currently logged in as: smehmood (ai-hacking-2025) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/Users/smehmood/src/smol-course/2_preference_alignment/notebooks/wandb/run-20250326_132023-izokf76r</code>
# Syncing run <strong><a href='https://wandb.ai/ai-hacking-2025/smol-course-smehmood/runs/izokf76r' target="_blank">smol_dpo_output</a></strong> to <a href='https://wandb.ai/ai-hacking-2025/smol-course-smehmood' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ai-hacking-2025/smol-course-smehmood' target="_blank">https://wandb.ai/ai-hacking-2025/smol-course-smehmood</a>
#  View run at <a href='https://wandb.ai/ai-hacking-2025/smol-course-smehmood/runs/izokf76r' target="_blank">https://wandb.ai/ai-hacking-2025/smol-course-smehmood/runs/izokf76r</a>
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#   0%|          | 0/200 [00:00<?, ?it/s]
# /Users/smehmood/src/smol-course/.venv/lib/python3.11/site-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
# {'loss': 0.6931, 'grad_norm': 80.07968139648438, 'learning_rate': 5.000000000000001e-07, 'rewards/chosen': 0.0, 'rewards/rejected': 0.0, 'rewards/accuracies': 0.0, 'rewards/margins': 0.0, 'logps/chosen': -453.0740966796875, 'logps/rejected': -332.3141174316406, 'logits/chosen': 4.749670028686523, 'logits/rejected': 4.0168962478637695, 'epoch': 0.0}
# {'loss': 0.6931, 'grad_norm': 83.99858856201172, 'learning_rate': 1.0000000000000002e-06, 'rewards/chosen': 0.0, 'rewards/rejected': 0.0, 'rewards/accuracies': 0.0, 'rewards/margins': 0.0, 'logps/chosen': -448.38018798828125, 'logps/rejected': -387.2480773925781, 'logits/chosen': 4.01844596862793, 'logits/rejected': 5.057215690612793, 'epoch': 0.0}
# {'loss': 0.6929, 'grad_norm': 91.29759216308594, 'learning_rate': 1.5e-06, 'rewards/chosen': 0.00029554887441918254, 'rewards/rejected': -0.00018897057452704757, 'rewards/accuracies': 0.625, 'rewards/margins': 0.00048451946349814534, 'logps/chosen': -632.2387084960938, 'logps/rejected': -477.20355224609375, 'logits/chosen': 3.6913161277770996, 'logits/rejected': 4.1555376052856445, 'epoch': 0.0}
# {'loss': 0.6932, 'grad_norm': 63.69062042236328, 'learning_rate': 2.0000000000000003e-06, 'rewards/chosen': -0.000731681298930198, 'rewards/rejected': -0.0007223725551739335, 'rewards/accuracies': 0.4375, 'rewards/margins': -9.308772860094905e-06, 'logps/chosen': -265.04107666015625, 'logps/rejected': -271.48828125, 'logits/chosen': 4.102466106414795, 'logits/rejected': 4.155620098114014, 'epoch': 0.0}
# {'loss': 0.6922, 'grad_norm': 69.84165954589844, 'learning_rate': 2.5e-06, 'rewards/chosen': -0.0007167161675170064, 'rewards/rejected': -0.002576816128566861, 'rewards/accuracies': 0.625, 'rewards/margins': 0.0018601000774651766, 'logps/chosen': -311.2593688964844, 'logps/rejected': -255.71725463867188, 'logits/chosen': 3.2282052040100098, 'logits/rejected': 3.81365704536438, 'epoch': 0.0}
# {'loss': 0.6916, 'grad_norm': 62.49797439575195, 'learning_rate': 3e-06, 'rewards/chosen': -1.7438840586692095e-05, 'rewards/rejected': -0.0031372893135994673, 'rewards/accuracies': 0.625, 'rewards/margins': 0.003119850531220436, 'logps/chosen': -294.963623046875, 'logps/rejected': -221.86888122558594, 'logits/chosen': 3.982821226119995, 'logits/rejected': 4.8620686531066895, 'epoch': 0.0}
# {'loss': 0.6899, 'grad_norm': 93.4521484375, 'learning_rate': 3.5000000000000004e-06, 'rewards/chosen': 0.0026485444977879524, 'rewards/rejected': -0.003980988636612892, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.006629533134400845, 'logps/chosen': -544.344970703125, 'logps/rejected': -305.78753662109375, 'logits/chosen': 3.7335903644561768, 'logits/rejected': 2.63503098487854, 'epoch': 0.0}
# {'loss': 0.6898, 'grad_norm': 79.66310119628906, 'learning_rate': 4.000000000000001e-06, 'rewards/chosen': 8.046627044677734e-06, 'rewards/rejected': -0.006818437948822975, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.006826484575867653, 'logps/chosen': -454.544189453125, 'logps/rejected': -346.89984130859375, 'logits/chosen': 3.3667056560516357, 'logits/rejected': 4.4150238037109375, 'epoch': 0.0}
# {'loss': 0.6914, 'grad_norm': 83.57422637939453, 'learning_rate': 4.5e-06, 'rewards/chosen': -0.0016718447441235185, 'rewards/rejected': -0.005351180210709572, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.003679336281493306, 'logps/chosen': -417.6726989746094, 'logps/rejected': -418.291259765625, 'logits/chosen': 3.5081610679626465, 'logits/rejected': 3.4428234100341797, 'epoch': 0.0}
# {'loss': 0.6907, 'grad_norm': 71.3425064086914, 'learning_rate': 5e-06, 'rewards/chosen': -0.00811390858143568, 'rewards/rejected': -0.013228083960711956, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.005114173982292414, 'logps/chosen': -276.4176940917969, 'logps/rejected': -340.51397705078125, 'logits/chosen': 4.382511138916016, 'logits/rejected': 4.0421905517578125, 'epoch': 0.0}
# {'loss': 0.6868, 'grad_norm': 80.41278839111328, 'learning_rate': 5.500000000000001e-06, 'rewards/chosen': -0.004031014163047075, 'rewards/rejected': -0.017005853354930878, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.012974840588867664, 'logps/chosen': -407.8368835449219, 'logps/rejected': -340.9503479003906, 'logits/chosen': 3.941485643386841, 'logits/rejected': 4.173540115356445, 'epoch': 0.0}
# {'loss': 0.6856, 'grad_norm': 90.72978210449219, 'learning_rate': 6e-06, 'rewards/chosen': 0.0019301080610603094, 'rewards/rejected': -0.013590313494205475, 'rewards/accuracies': 0.625, 'rewards/margins': 0.015520419925451279, 'logps/chosen': -450.8255920410156, 'logps/rejected': -506.7886962890625, 'logits/chosen': 2.7242250442504883, 'logits/rejected': 4.072840690612793, 'epoch': 0.0}
# {'loss': 0.6883, 'grad_norm': 92.4884262084961, 'learning_rate': 6.5000000000000004e-06, 'rewards/chosen': -0.005727225914597511, 'rewards/rejected': -0.015801668167114258, 'rewards/accuracies': 0.625, 'rewards/margins': 0.010074442252516747, 'logps/chosen': -489.0169677734375, 'logps/rejected': -449.2898864746094, 'logits/chosen': 5.24355411529541, 'logits/rejected': 4.201587200164795, 'epoch': 0.0}
# {'loss': 0.6819, 'grad_norm': 76.67082977294922, 'learning_rate': 7.000000000000001e-06, 'rewards/chosen': -0.005589345935732126, 'rewards/rejected': -0.028554905205965042, 'rewards/accuracies': 0.625, 'rewards/margins': 0.022965559735894203, 'logps/chosen': -357.46417236328125, 'logps/rejected': -284.6377868652344, 'logits/chosen': 3.0650112628936768, 'logits/rejected': 4.414785385131836, 'epoch': 0.0}
# {'loss': 0.6861, 'grad_norm': 74.7168197631836, 'learning_rate': 7.5e-06, 'rewards/chosen': -0.013479450717568398, 'rewards/rejected': -0.028590891510248184, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.015111439861357212, 'logps/chosen': -409.7568664550781, 'logps/rejected': -320.992431640625, 'logits/chosen': 2.4401752948760986, 'logits/rejected': 2.6438937187194824, 'epoch': 0.0}
# {'loss': 0.689, 'grad_norm': 89.95466613769531, 'learning_rate': 8.000000000000001e-06, 'rewards/chosen': -0.02970646694302559, 'rewards/rejected': -0.03903551772236824, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.009329049848020077, 'logps/chosen': -455.3248291015625, 'logps/rejected': -341.31805419921875, 'logits/chosen': 4.688669204711914, 'logits/rejected': 4.066197395324707, 'epoch': 0.0}
# {'loss': 0.6954, 'grad_norm': 79.85325622558594, 'learning_rate': 8.500000000000002e-06, 'rewards/chosen': -0.01976189762353897, 'rewards/rejected': -0.016770273447036743, 'rewards/accuracies': 0.25, 'rewards/margins': -0.0029916223138570786, 'logps/chosen': -441.2557373046875, 'logps/rejected': -391.0140380859375, 'logits/chosen': 1.991519808769226, 'logits/rejected': 2.703293800354004, 'epoch': 0.0}
# {'loss': 0.6699, 'grad_norm': 76.46350860595703, 'learning_rate': 9e-06, 'rewards/chosen': -0.03305584937334061, 'rewards/rejected': -0.08267895877361298, 'rewards/accuracies': 0.75, 'rewards/margins': 0.04962310940027237, 'logps/chosen': -461.68292236328125, 'logps/rejected': -329.45074462890625, 'logits/chosen': 2.860969066619873, 'logits/rejected': 2.8596527576446533, 'epoch': 0.0}
# {'loss': 0.673, 'grad_norm': 78.44779968261719, 'learning_rate': 9.5e-06, 'rewards/chosen': -0.038206547498703, 'rewards/rejected': -0.08396849781274796, 'rewards/accuracies': 0.5, 'rewards/margins': 0.04576195031404495, 'logps/chosen': -413.4148254394531, 'logps/rejected': -342.2600402832031, 'logits/chosen': 3.4095306396484375, 'logits/rejected': 3.6668505668640137, 'epoch': 0.0}
# {'loss': 0.6646, 'grad_norm': 68.68602752685547, 'learning_rate': 1e-05, 'rewards/chosen': -0.03205138444900513, 'rewards/rejected': -0.09176192432641983, 'rewards/accuracies': 0.75, 'rewards/margins': 0.0597105398774147, 'logps/chosen': -355.30487060546875, 'logps/rejected': -291.96551513671875, 'logits/chosen': 3.417764186859131, 'logits/rejected': 3.8854422569274902, 'epoch': 0.01}
# {'loss': 0.6555, 'grad_norm': 71.81109619140625, 'learning_rate': 1.05e-05, 'rewards/chosen': -0.012754798866808414, 'rewards/rejected': -0.09737788140773773, 'rewards/accuracies': 0.625, 'rewards/margins': 0.0846230760216713, 'logps/chosen': -436.2246398925781, 'logps/rejected': -374.49432373046875, 'logits/chosen': 4.336606025695801, 'logits/rejected': 4.119189262390137, 'epoch': 0.01}
# {'loss': 0.6577, 'grad_norm': 75.5760726928711, 'learning_rate': 1.1000000000000001e-05, 'rewards/chosen': -0.013302857987582684, 'rewards/rejected': -0.09282897412776947, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.07952611893415451, 'logps/chosen': -483.1461486816406, 'logps/rejected': -401.793212890625, 'logits/chosen': 4.45823860168457, 'logits/rejected': 3.8188095092773438, 'epoch': 0.01}
# {'loss': 0.6885, 'grad_norm': 71.32766723632812, 'learning_rate': 1.1500000000000002e-05, 'rewards/chosen': -0.07343414425849915, 'rewards/rejected': -0.08824615925550461, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.014812011271715164, 'logps/chosen': -250.1458282470703, 'logps/rejected': -278.795166015625, 'logits/chosen': 3.6755404472351074, 'logits/rejected': 4.19240665435791, 'epoch': 0.01}
# {'loss': 0.677, 'grad_norm': 73.72454071044922, 'learning_rate': 1.2e-05, 'rewards/chosen': -0.026606017723679543, 'rewards/rejected': -0.07249902933835983, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.04589301347732544, 'logps/chosen': -459.7215576171875, 'logps/rejected': -417.89813232421875, 'logits/chosen': 3.2078046798706055, 'logits/rejected': 3.134733200073242, 'epoch': 0.01}
# {'loss': 0.6638, 'grad_norm': 62.69183349609375, 'learning_rate': 1.25e-05, 'rewards/chosen': -0.062314458191394806, 'rewards/rejected': -0.1282961070537567, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.0659816637635231, 'logps/chosen': -427.72442626953125, 'logps/rejected': -237.845947265625, 'logits/chosen': 3.0211169719696045, 'logits/rejected': 2.9670615196228027, 'epoch': 0.01}
# {'loss': 0.6417, 'grad_norm': 67.55133819580078, 'learning_rate': 1.3000000000000001e-05, 'rewards/chosen': -0.020697301253676414, 'rewards/rejected': -0.13579925894737244, 'rewards/accuracies': 0.625, 'rewards/margins': 0.11510196328163147, 'logps/chosen': -329.0376892089844, 'logps/rejected': -224.05307006835938, 'logits/chosen': 4.2999467849731445, 'logits/rejected': 3.9650378227233887, 'epoch': 0.01}
# {'loss': 0.651, 'grad_norm': 72.33590698242188, 'learning_rate': 1.3500000000000001e-05, 'rewards/chosen': -0.06487911939620972, 'rewards/rejected': -0.1579877883195877, 'rewards/accuracies': 0.75, 'rewards/margins': 0.09310866892337799, 'logps/chosen': -344.7129821777344, 'logps/rejected': -305.0926513671875, 'logits/chosen': 4.1743974685668945, 'logits/rejected': 4.347294807434082, 'epoch': 0.01}
# {'loss': 0.6347, 'grad_norm': 75.06230926513672, 'learning_rate': 1.4000000000000001e-05, 'rewards/chosen': -0.022088337689638138, 'rewards/rejected': -0.17629727721214294, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.1542089581489563, 'logps/chosen': -313.3349304199219, 'logps/rejected': -427.48809814453125, 'logits/chosen': 2.8220160007476807, 'logits/rejected': 3.8425533771514893, 'epoch': 0.01}
# {'loss': 0.6447, 'grad_norm': 90.48063659667969, 'learning_rate': 1.45e-05, 'rewards/chosen': -0.11176507920026779, 'rewards/rejected': -0.2190324068069458, 'rewards/accuracies': 0.75, 'rewards/margins': 0.1072673350572586, 'logps/chosen': -581.4236450195312, 'logps/rejected': -482.2353515625, 'logits/chosen': 3.3464388847351074, 'logits/rejected': 2.889284610748291, 'epoch': 0.01}
# {'loss': 0.6586, 'grad_norm': 62.255882263183594, 'learning_rate': 1.5e-05, 'rewards/chosen': -0.058131054043769836, 'rewards/rejected': -0.14313629269599915, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.08500523865222931, 'logps/chosen': -322.945068359375, 'logps/rejected': -243.93125915527344, 'logits/chosen': 3.1624317169189453, 'logits/rejected': 2.598137617111206, 'epoch': 0.01}
# {'loss': 0.6854, 'grad_norm': 91.9966812133789, 'learning_rate': 1.55e-05, 'rewards/chosen': -0.16776055097579956, 'rewards/rejected': -0.20589852333068848, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.038137972354888916, 'logps/chosen': -513.97998046875, 'logps/rejected': -428.79376220703125, 'logits/chosen': 4.616964817047119, 'logits/rejected': 3.8838634490966797, 'epoch': 0.01}
# {'loss': 0.6239, 'grad_norm': 55.22549057006836, 'learning_rate': 1.6000000000000003e-05, 'rewards/chosen': -0.0033581387251615524, 'rewards/rejected': -0.16357001662254333, 'rewards/accuracies': 0.625, 'rewards/margins': 0.16021189093589783, 'logps/chosen': -248.81845092773438, 'logps/rejected': -188.30201721191406, 'logits/chosen': 4.287877082824707, 'logits/rejected': 4.297150611877441, 'epoch': 0.01}
# {'loss': 0.6768, 'grad_norm': 64.70381164550781, 'learning_rate': 1.65e-05, 'rewards/chosen': -0.14780139923095703, 'rewards/rejected': -0.20738856494426727, 'rewards/accuracies': 0.625, 'rewards/margins': 0.059587180614471436, 'logps/chosen': -294.6258544921875, 'logps/rejected': -265.5333251953125, 'logits/chosen': 3.046941041946411, 'logits/rejected': 4.668684005737305, 'epoch': 0.01}
# {'loss': 0.6775, 'grad_norm': 75.36317443847656, 'learning_rate': 1.7000000000000003e-05, 'rewards/chosen': -0.21659474074840546, 'rewards/rejected': -0.2719220221042633, 'rewards/accuracies': 0.5, 'rewards/margins': 0.055327288806438446, 'logps/chosen': -474.95068359375, 'logps/rejected': -399.95452880859375, 'logits/chosen': 3.1671640872955322, 'logits/rejected': 2.621060848236084, 'epoch': 0.01}
# {'loss': 0.6538, 'grad_norm': 64.07003784179688, 'learning_rate': 1.75e-05, 'rewards/chosen': -0.16304437816143036, 'rewards/rejected': -0.269102543592453, 'rewards/accuracies': 0.75, 'rewards/margins': 0.10605818033218384, 'logps/chosen': -302.1512451171875, 'logps/rejected': -293.8768615722656, 'logits/chosen': 2.5008981227874756, 'logits/rejected': 2.4541749954223633, 'epoch': 0.01}
# {'loss': 0.6063, 'grad_norm': 70.8192367553711, 'learning_rate': 1.8e-05, 'rewards/chosen': -0.17830371856689453, 'rewards/rejected': -0.4130535125732422, 'rewards/accuracies': 0.5, 'rewards/margins': 0.23474976420402527, 'logps/chosen': -495.69781494140625, 'logps/rejected': -307.1130676269531, 'logits/chosen': 3.370387315750122, 'logits/rejected': 3.9210972785949707, 'epoch': 0.01}
# {'loss': 0.7219, 'grad_norm': 89.08328247070312, 'learning_rate': 1.85e-05, 'rewards/chosen': -0.27645015716552734, 'rewards/rejected': -0.26962941884994507, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.006820745766162872, 'logps/chosen': -447.55523681640625, 'logps/rejected': -437.0176086425781, 'logits/chosen': 3.246798038482666, 'logits/rejected': 2.7551286220550537, 'epoch': 0.01}
# {'loss': 0.6217, 'grad_norm': 73.7433853149414, 'learning_rate': 1.9e-05, 'rewards/chosen': -0.16910512745380402, 'rewards/rejected': -0.38141995668411255, 'rewards/accuracies': 0.625, 'rewards/margins': 0.21231484413146973, 'logps/chosen': -327.06732177734375, 'logps/rejected': -374.90618896484375, 'logits/chosen': 3.541910409927368, 'logits/rejected': 4.290595054626465, 'epoch': 0.01}
# {'loss': 0.6524, 'grad_norm': 91.41016387939453, 'learning_rate': 1.9500000000000003e-05, 'rewards/chosen': -0.1301870346069336, 'rewards/rejected': -0.24737095832824707, 'rewards/accuracies': 0.625, 'rewards/margins': 0.11718393862247467, 'logps/chosen': -630.902099609375, 'logps/rejected': -455.1188659667969, 'logits/chosen': 3.488126754760742, 'logits/rejected': 2.91176700592041, 'epoch': 0.01}
# {'loss': 0.7032, 'grad_norm': 71.83985900878906, 'learning_rate': 2e-05, 'rewards/chosen': -0.24096839129924774, 'rewards/rejected': -0.2862870693206787, 'rewards/accuracies': 0.5, 'rewards/margins': 0.04531867802143097, 'logps/chosen': -318.32855224609375, 'logps/rejected': -370.447998046875, 'logits/chosen': 3.5383949279785156, 'logits/rejected': 4.245586395263672, 'epoch': 0.01}
# {'loss': 0.6553, 'grad_norm': 78.47564697265625, 'learning_rate': 2.05e-05, 'rewards/chosen': -0.19043070077896118, 'rewards/rejected': -0.3049667477607727, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.11453606188297272, 'logps/chosen': -506.1225280761719, 'logps/rejected': -372.39471435546875, 'logits/chosen': 3.1078784465789795, 'logits/rejected': 3.8626835346221924, 'epoch': 0.01}
# {'loss': 0.7453, 'grad_norm': 87.64089965820312, 'learning_rate': 2.1e-05, 'rewards/chosen': -0.3378027379512787, 'rewards/rejected': -0.3030121922492981, 'rewards/accuracies': 0.5, 'rewards/margins': -0.034790512174367905, 'logps/chosen': -390.6568908691406, 'logps/rejected': -409.815185546875, 'logits/chosen': 4.637576103210449, 'logits/rejected': 3.8889946937561035, 'epoch': 0.01}
# {'loss': 0.6042, 'grad_norm': 83.26045989990234, 'learning_rate': 2.15e-05, 'rewards/chosen': -0.31519657373428345, 'rewards/rejected': -0.6098916530609131, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.29469507932662964, 'logps/chosen': -529.1543579101562, 'logps/rejected': -459.0838317871094, 'logits/chosen': 2.609447479248047, 'logits/rejected': 3.727602005004883, 'epoch': 0.01}
# {'loss': 0.7564, 'grad_norm': 71.71851348876953, 'learning_rate': 2.2000000000000003e-05, 'rewards/chosen': -0.3328443169593811, 'rewards/rejected': -0.2630743384361267, 'rewards/accuracies': 0.5, 'rewards/margins': -0.06976998597383499, 'logps/chosen': -254.82406616210938, 'logps/rejected': -244.1755828857422, 'logits/chosen': 4.402461051940918, 'logits/rejected': 3.574553966522217, 'epoch': 0.01}
# {'loss': 0.6174, 'grad_norm': 81.99669647216797, 'learning_rate': 2.25e-05, 'rewards/chosen': -0.20020318031311035, 'rewards/rejected': -0.3964938521385193, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.19629065692424774, 'logps/chosen': -639.108154296875, 'logps/rejected': -428.51202392578125, 'logits/chosen': 3.1776559352874756, 'logits/rejected': 3.410702705383301, 'epoch': 0.01}
# {'loss': 0.6297, 'grad_norm': 77.1533203125, 'learning_rate': 2.3000000000000003e-05, 'rewards/chosen': -0.14145949482917786, 'rewards/rejected': -0.4002428352832794, 'rewards/accuracies': 0.75, 'rewards/margins': 0.25878334045410156, 'logps/chosen': -472.9726257324219, 'logps/rejected': -337.20343017578125, 'logits/chosen': 2.7490642070770264, 'logits/rejected': 1.6908061504364014, 'epoch': 0.01}
# {'loss': 0.6225, 'grad_norm': 70.67896270751953, 'learning_rate': 2.35e-05, 'rewards/chosen': -0.3114669919013977, 'rewards/rejected': -0.5829303860664368, 'rewards/accuracies': 0.5, 'rewards/margins': 0.27146339416503906, 'logps/chosen': -398.29644775390625, 'logps/rejected': -403.41571044921875, 'logits/chosen': 3.5332562923431396, 'logits/rejected': 3.507096290588379, 'epoch': 0.01}
# {'loss': 0.574, 'grad_norm': 64.89385986328125, 'learning_rate': 2.4e-05, 'rewards/chosen': -0.10087526589632034, 'rewards/rejected': -0.4037022292613983, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.3028269410133362, 'logps/chosen': -375.8780517578125, 'logps/rejected': -265.64996337890625, 'logits/chosen': 4.648466110229492, 'logits/rejected': 4.614197254180908, 'epoch': 0.01}
# {'loss': 0.5796, 'grad_norm': 67.92715454101562, 'learning_rate': 2.45e-05, 'rewards/chosen': -0.2938920557498932, 'rewards/rejected': -0.710735559463501, 'rewards/accuracies': 0.625, 'rewards/margins': 0.4168435335159302, 'logps/chosen': -567.6771850585938, 'logps/rejected': -494.914306640625, 'logits/chosen': 3.4530599117279053, 'logits/rejected': 3.959005832672119, 'epoch': 0.01}
# {'loss': 0.6114, 'grad_norm': 74.0414810180664, 'learning_rate': 2.5e-05, 'rewards/chosen': -0.17730577290058136, 'rewards/rejected': -0.39507627487182617, 'rewards/accuracies': 0.625, 'rewards/margins': 0.21777048707008362, 'logps/chosen': -389.8758544921875, 'logps/rejected': -361.7513427734375, 'logits/chosen': 3.662130832672119, 'logits/rejected': 3.9591760635375977, 'epoch': 0.01}
# {'loss': 0.6227, 'grad_norm': 68.47980499267578, 'learning_rate': 2.5500000000000003e-05, 'rewards/chosen': -0.25779932737350464, 'rewards/rejected': -0.46113383769989014, 'rewards/accuracies': 0.75, 'rewards/margins': 0.20333456993103027, 'logps/chosen': -383.5322570800781, 'logps/rejected': -317.7961730957031, 'logits/chosen': 1.9478003978729248, 'logits/rejected': 1.8884997367858887, 'epoch': 0.01}
# {'loss': 0.7485, 'grad_norm': 73.68806457519531, 'learning_rate': 2.6000000000000002e-05, 'rewards/chosen': -0.3161903917789459, 'rewards/rejected': -0.2929339110851288, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.023256488144397736, 'logps/chosen': -435.9349365234375, 'logps/rejected': -333.01312255859375, 'logits/chosen': 3.3620007038116455, 'logits/rejected': 3.0323147773742676, 'epoch': 0.01}
# {'loss': 0.7338, 'grad_norm': 91.89200592041016, 'learning_rate': 2.6500000000000004e-05, 'rewards/chosen': -0.2781370282173157, 'rewards/rejected': -0.3476670980453491, 'rewards/accuracies': 0.625, 'rewards/margins': 0.06953009217977524, 'logps/chosen': -389.7947998046875, 'logps/rejected': -445.477294921875, 'logits/chosen': 2.8382158279418945, 'logits/rejected': 3.6037158966064453, 'epoch': 0.01}
# {'loss': 0.7336, 'grad_norm': 82.91143035888672, 'learning_rate': 2.7000000000000002e-05, 'rewards/chosen': -0.6268144845962524, 'rewards/rejected': -0.6339019536972046, 'rewards/accuracies': 0.625, 'rewards/margins': 0.007087528705596924, 'logps/chosen': -413.56884765625, 'logps/rejected': -301.0881652832031, 'logits/chosen': 3.069566249847412, 'logits/rejected': 3.9862444400787354, 'epoch': 0.01}
# {'loss': 0.8191, 'grad_norm': 128.82711791992188, 'learning_rate': 2.7500000000000004e-05, 'rewards/chosen': -0.5394338965415955, 'rewards/rejected': -0.5207850337028503, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.018648892641067505, 'logps/chosen': -521.974853515625, 'logps/rejected': -472.8326416015625, 'logits/chosen': 3.955505847930908, 'logits/rejected': 5.030300617218018, 'epoch': 0.01}
# {'loss': 0.7691, 'grad_norm': 81.98645782470703, 'learning_rate': 2.8000000000000003e-05, 'rewards/chosen': -0.2550661861896515, 'rewards/rejected': -0.25754469633102417, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.0024785473942756653, 'logps/chosen': -325.968505859375, 'logps/rejected': -277.01947021484375, 'logits/chosen': 3.8311591148376465, 'logits/rejected': 4.30068302154541, 'epoch': 0.01}
# {'loss': 0.5369, 'grad_norm': 64.06767272949219, 'learning_rate': 2.8499999999999998e-05, 'rewards/chosen': -0.20681457221508026, 'rewards/rejected': -0.7298707962036133, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5230562686920166, 'logps/chosen': -283.1065368652344, 'logps/rejected': -428.82305908203125, 'logits/chosen': 4.41648006439209, 'logits/rejected': 3.731168270111084, 'epoch': 0.01}
# {'loss': 0.5584, 'grad_norm': 66.018798828125, 'learning_rate': 2.9e-05, 'rewards/chosen': -0.19497117400169373, 'rewards/rejected': -0.5386884212493896, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.3437172770500183, 'logps/chosen': -444.808837890625, 'logps/rejected': -265.1935729980469, 'logits/chosen': 3.3493218421936035, 'logits/rejected': 2.747373580932617, 'epoch': 0.01}
# {'loss': 0.7388, 'grad_norm': 73.41568756103516, 'learning_rate': 2.95e-05, 'rewards/chosen': -0.5052546262741089, 'rewards/rejected': -0.47726985812187195, 'rewards/accuracies': 0.375, 'rewards/margins': -0.02798473834991455, 'logps/chosen': -376.64239501953125, 'logps/rejected': -390.9468078613281, 'logits/chosen': 3.3603906631469727, 'logits/rejected': 3.1217408180236816, 'epoch': 0.02}
# {'loss': 0.6294, 'grad_norm': 69.15081787109375, 'learning_rate': 3e-05, 'rewards/chosen': -0.5454849004745483, 'rewards/rejected': -0.7690478563308716, 'rewards/accuracies': 0.75, 'rewards/margins': 0.22356295585632324, 'logps/chosen': -375.6644592285156, 'logps/rejected': -298.9549255371094, 'logits/chosen': 3.482481002807617, 'logits/rejected': 3.5118794441223145, 'epoch': 0.02}
# {'loss': 0.5647, 'grad_norm': 61.21234130859375, 'learning_rate': 3.05e-05, 'rewards/chosen': -0.21075540781021118, 'rewards/rejected': -0.6008154153823853, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.39006003737449646, 'logps/chosen': -340.7339172363281, 'logps/rejected': -308.16717529296875, 'logits/chosen': 2.6745808124542236, 'logits/rejected': 2.441235065460205, 'epoch': 0.02}
# {'loss': 0.7038, 'grad_norm': 72.33895874023438, 'learning_rate': 3.1e-05, 'rewards/chosen': -0.267632395029068, 'rewards/rejected': -0.3450276851654053, 'rewards/accuracies': 0.375, 'rewards/margins': 0.07739527523517609, 'logps/chosen': -443.32147216796875, 'logps/rejected': -316.82708740234375, 'logits/chosen': 4.2468695640563965, 'logits/rejected': 3.50874662399292, 'epoch': 0.02}
# {'loss': 0.6261, 'grad_norm': 100.28684997558594, 'learning_rate': 3.15e-05, 'rewards/chosen': -0.5666614174842834, 'rewards/rejected': -0.8660563826560974, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.2993949353694916, 'logps/chosen': -493.820556640625, 'logps/rejected': -358.38067626953125, 'logits/chosen': 2.893653392791748, 'logits/rejected': 3.1282403469085693, 'epoch': 0.02}
# {'loss': 0.6029, 'grad_norm': 79.45284271240234, 'learning_rate': 3.2000000000000005e-05, 'rewards/chosen': -0.24478964507579803, 'rewards/rejected': -0.5089877843856812, 'rewards/accuracies': 0.75, 'rewards/margins': 0.26419809460639954, 'logps/chosen': -436.7019958496094, 'logps/rejected': -385.4810791015625, 'logits/chosen': 3.678901433944702, 'logits/rejected': 3.7553327083587646, 'epoch': 0.02}
# {'loss': 0.8323, 'grad_norm': 82.52511596679688, 'learning_rate': 3.2500000000000004e-05, 'rewards/chosen': -0.4145258069038391, 'rewards/rejected': -0.27419760823249817, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.14032819867134094, 'logps/chosen': -255.80078125, 'logps/rejected': -326.08306884765625, 'logits/chosen': 2.864503860473633, 'logits/rejected': 2.7805967330932617, 'epoch': 0.02}
# {'loss': 0.6117, 'grad_norm': 64.5121078491211, 'learning_rate': 3.3e-05, 'rewards/chosen': -0.42873716354370117, 'rewards/rejected': -0.6522682905197144, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.22353114187717438, 'logps/chosen': -355.22039794921875, 'logps/rejected': -215.29901123046875, 'logits/chosen': 3.4269723892211914, 'logits/rejected': 3.265474796295166, 'epoch': 0.02}
# {'loss': 0.6063, 'grad_norm': 79.48181915283203, 'learning_rate': 3.35e-05, 'rewards/chosen': -0.3959310054779053, 'rewards/rejected': -0.6363951563835144, 'rewards/accuracies': 0.625, 'rewards/margins': 0.2404642105102539, 'logps/chosen': -521.1360473632812, 'logps/rejected': -403.94891357421875, 'logits/chosen': 3.574948787689209, 'logits/rejected': 3.1529481410980225, 'epoch': 0.02}
# {'loss': 0.6739, 'grad_norm': 91.40982818603516, 'learning_rate': 3.4000000000000007e-05, 'rewards/chosen': -0.4859016537666321, 'rewards/rejected': -0.5764172077178955, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.09051556140184402, 'logps/chosen': -523.991943359375, 'logps/rejected': -446.37152099609375, 'logits/chosen': 2.9101223945617676, 'logits/rejected': 3.50634765625, 'epoch': 0.02}
# {'loss': 0.7024, 'grad_norm': 99.65573120117188, 'learning_rate': 3.45e-05, 'rewards/chosen': -0.3870815932750702, 'rewards/rejected': -0.6054201126098633, 'rewards/accuracies': 0.625, 'rewards/margins': 0.21833853423595428, 'logps/chosen': -519.7904663085938, 'logps/rejected': -410.80169677734375, 'logits/chosen': 3.442699670791626, 'logits/rejected': 2.9375760555267334, 'epoch': 0.02}
# {'loss': 0.6366, 'grad_norm': 97.14480590820312, 'learning_rate': 3.5e-05, 'rewards/chosen': -0.5747123956680298, 'rewards/rejected': -0.7947568297386169, 'rewards/accuracies': 0.625, 'rewards/margins': 0.22004440426826477, 'logps/chosen': -515.6934814453125, 'logps/rejected': -461.6469421386719, 'logits/chosen': 2.5881507396698, 'logits/rejected': 3.2166547775268555, 'epoch': 0.02}
# {'loss': 0.6467, 'grad_norm': 68.0430679321289, 'learning_rate': 3.55e-05, 'rewards/chosen': -0.2652466595172882, 'rewards/rejected': -0.5221647620201111, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.2569181025028229, 'logps/chosen': -399.357177734375, 'logps/rejected': -347.64373779296875, 'logits/chosen': 2.8195981979370117, 'logits/rejected': 3.593667507171631, 'epoch': 0.02}
# {'loss': 0.6537, 'grad_norm': 87.10749053955078, 'learning_rate': 3.6e-05, 'rewards/chosen': -0.44657590985298157, 'rewards/rejected': -0.6558645963668823, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.20928862690925598, 'logps/chosen': -546.533203125, 'logps/rejected': -449.23797607421875, 'logits/chosen': 3.749351739883423, 'logits/rejected': 3.7237181663513184, 'epoch': 0.02}
# {'loss': 0.5802, 'grad_norm': 89.81777954101562, 'learning_rate': 3.65e-05, 'rewards/chosen': -0.6156270503997803, 'rewards/rejected': -1.0354208946228027, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.4197937548160553, 'logps/chosen': -618.7302856445312, 'logps/rejected': -466.19134521484375, 'logits/chosen': 3.2238821983337402, 'logits/rejected': 2.6322100162506104, 'epoch': 0.02}
# {'loss': 0.6845, 'grad_norm': 92.59764862060547, 'learning_rate': 3.7e-05, 'rewards/chosen': -0.655767560005188, 'rewards/rejected': -0.8312092423439026, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.17544162273406982, 'logps/chosen': -518.0507202148438, 'logps/rejected': -348.1282958984375, 'logits/chosen': 1.7308765649795532, 'logits/rejected': 1.492525339126587, 'epoch': 0.02}
# {'loss': 0.7276, 'grad_norm': 74.86180114746094, 'learning_rate': 3.7500000000000003e-05, 'rewards/chosen': -0.4483933746814728, 'rewards/rejected': -0.4675293564796448, 'rewards/accuracies': 0.5, 'rewards/margins': 0.019135959446430206, 'logps/chosen': -438.1484069824219, 'logps/rejected': -274.8652038574219, 'logits/chosen': 3.4114627838134766, 'logits/rejected': 2.4146480560302734, 'epoch': 0.02}
# {'loss': 0.5858, 'grad_norm': 84.1057357788086, 'learning_rate': 3.8e-05, 'rewards/chosen': -0.4037323594093323, 'rewards/rejected': -0.7594225406646729, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.3556901812553406, 'logps/chosen': -591.5528564453125, 'logps/rejected': -580.6865234375, 'logits/chosen': 2.305243968963623, 'logits/rejected': 3.605100154876709, 'epoch': 0.02}
# {'loss': 0.5651, 'grad_norm': 68.7470932006836, 'learning_rate': 3.85e-05, 'rewards/chosen': -0.25307995080947876, 'rewards/rejected': -0.6489055752754211, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.39582559466362, 'logps/chosen': -477.7122802734375, 'logps/rejected': -444.6740417480469, 'logits/chosen': 3.527548313140869, 'logits/rejected': 2.925693988800049, 'epoch': 0.02}
# {'loss': 0.5863, 'grad_norm': 69.40939331054688, 'learning_rate': 3.9000000000000006e-05, 'rewards/chosen': -0.4420788586139679, 'rewards/rejected': -0.8381509780883789, 'rewards/accuracies': 0.625, 'rewards/margins': 0.3960721492767334, 'logps/chosen': -592.7593383789062, 'logps/rejected': -389.8013916015625, 'logits/chosen': 4.252669334411621, 'logits/rejected': 2.5156028270721436, 'epoch': 0.02}
# {'loss': 0.493, 'grad_norm': 67.0168228149414, 'learning_rate': 3.9500000000000005e-05, 'rewards/chosen': -0.41258570551872253, 'rewards/rejected': -0.9614449739456177, 'rewards/accuracies': 0.875, 'rewards/margins': 0.5488592386245728, 'logps/chosen': -505.94952392578125, 'logps/rejected': -481.6665344238281, 'logits/chosen': 3.660162925720215, 'logits/rejected': 4.657878398895264, 'epoch': 0.02}
# {'loss': 0.7489, 'grad_norm': 104.45158386230469, 'learning_rate': 4e-05, 'rewards/chosen': -0.7357780933380127, 'rewards/rejected': -0.7956533432006836, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.059875279664993286, 'logps/chosen': -546.0068359375, 'logps/rejected': -617.1439819335938, 'logits/chosen': 2.498777151107788, 'logits/rejected': 3.0136685371398926, 'epoch': 0.02}
# {'loss': 0.895, 'grad_norm': 106.73987579345703, 'learning_rate': 4.05e-05, 'rewards/chosen': -0.8874229788780212, 'rewards/rejected': -0.6675865650177002, 'rewards/accuracies': 0.5, 'rewards/margins': -0.21983639895915985, 'logps/chosen': -473.60211181640625, 'logps/rejected': -555.1965942382812, 'logits/chosen': 1.699349284172058, 'logits/rejected': 2.3078598976135254, 'epoch': 0.02}
# {'loss': 0.7144, 'grad_norm': 78.6865005493164, 'learning_rate': 4.1e-05, 'rewards/chosen': -0.6909248232841492, 'rewards/rejected': -0.8053797483444214, 'rewards/accuracies': 0.375, 'rewards/margins': 0.11445494741201401, 'logps/chosen': -279.35498046875, 'logps/rejected': -318.59002685546875, 'logits/chosen': 3.4361255168914795, 'logits/rejected': 3.0519816875457764, 'epoch': 0.02}
# {'loss': 0.8783, 'grad_norm': 106.12311553955078, 'learning_rate': 4.15e-05, 'rewards/chosen': -0.7890602350234985, 'rewards/rejected': -0.8550351858139038, 'rewards/accuracies': 0.625, 'rewards/margins': 0.06597492843866348, 'logps/chosen': -468.49908447265625, 'logps/rejected': -364.93853759765625, 'logits/chosen': 2.2772865295410156, 'logits/rejected': 2.3504042625427246, 'epoch': 0.02}
# {'loss': 0.7272, 'grad_norm': 98.00110626220703, 'learning_rate': 4.2e-05, 'rewards/chosen': -0.6173039674758911, 'rewards/rejected': -0.7132665514945984, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.09596254676580429, 'logps/chosen': -438.33294677734375, 'logps/rejected': -482.73748779296875, 'logits/chosen': 2.716177463531494, 'logits/rejected': 2.816371202468872, 'epoch': 0.02}
# {'loss': 0.6677, 'grad_norm': 78.7225341796875, 'learning_rate': 4.25e-05, 'rewards/chosen': -0.5795206427574158, 'rewards/rejected': -0.7472242116928101, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.1677035689353943, 'logps/chosen': -485.38165283203125, 'logps/rejected': -351.628173828125, 'logits/chosen': 2.678283452987671, 'logits/rejected': 3.537652015686035, 'epoch': 0.02}
# {'loss': 0.7443, 'grad_norm': 84.22438049316406, 'learning_rate': 4.3e-05, 'rewards/chosen': -0.7310202717781067, 'rewards/rejected': -0.8207912445068359, 'rewards/accuracies': 0.625, 'rewards/margins': 0.08977100998163223, 'logps/chosen': -334.28216552734375, 'logps/rejected': -340.4858703613281, 'logits/chosen': 2.4953980445861816, 'logits/rejected': 3.2770965099334717, 'epoch': 0.02}
# {'loss': 0.4866, 'grad_norm': 53.664886474609375, 'learning_rate': 4.35e-05, 'rewards/chosen': -0.5126288533210754, 'rewards/rejected': -1.261541485786438, 'rewards/accuracies': 0.625, 'rewards/margins': 0.7489126324653625, 'logps/chosen': -274.44805908203125, 'logps/rejected': -372.99273681640625, 'logits/chosen': 2.405576229095459, 'logits/rejected': 3.2018141746520996, 'epoch': 0.02}
# {'loss': 0.7533, 'grad_norm': 89.15501403808594, 'learning_rate': 4.4000000000000006e-05, 'rewards/chosen': -0.6147587299346924, 'rewards/rejected': -0.5655606389045715, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.04919806495308876, 'logps/chosen': -440.697265625, 'logps/rejected': -323.8722839355469, 'logits/chosen': 3.3156015872955322, 'logits/rejected': 4.150759696960449, 'epoch': 0.02}
# {'loss': 0.693, 'grad_norm': 79.08721160888672, 'learning_rate': 4.4500000000000004e-05, 'rewards/chosen': -0.7255297899246216, 'rewards/rejected': -1.020546793937683, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.2950170040130615, 'logps/chosen': -494.1107177734375, 'logps/rejected': -399.33660888671875, 'logits/chosen': 2.2074263095855713, 'logits/rejected': 3.19172739982605, 'epoch': 0.02}
# {'loss': 0.6949, 'grad_norm': 73.90089416503906, 'learning_rate': 4.5e-05, 'rewards/chosen': -0.7903028726577759, 'rewards/rejected': -0.9397968053817749, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.149494007229805, 'logps/chosen': -514.6279296875, 'logps/rejected': -345.9667053222656, 'logits/chosen': 2.1569581031799316, 'logits/rejected': 1.871429681777954, 'epoch': 0.02}
# {'loss': 0.6768, 'grad_norm': 85.86908721923828, 'learning_rate': 4.55e-05, 'rewards/chosen': -0.5384727716445923, 'rewards/rejected': -0.6703041195869446, 'rewards/accuracies': 0.625, 'rewards/margins': 0.1318313181400299, 'logps/chosen': -428.1956787109375, 'logps/rejected': -385.06787109375, 'logits/chosen': 3.573152542114258, 'logits/rejected': 3.8513617515563965, 'epoch': 0.02}
# {'loss': 0.6536, 'grad_norm': 82.35352325439453, 'learning_rate': 4.600000000000001e-05, 'rewards/chosen': -0.7338002920150757, 'rewards/rejected': -0.9694522619247437, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.23565199971199036, 'logps/chosen': -628.818603515625, 'logps/rejected': -414.9140625, 'logits/chosen': 2.810011386871338, 'logits/rejected': 2.4330592155456543, 'epoch': 0.02}
# {'loss': 0.6148, 'grad_norm': 65.60665130615234, 'learning_rate': 4.6500000000000005e-05, 'rewards/chosen': -0.4614630341529846, 'rewards/rejected': -0.6928772330284119, 'rewards/accuracies': 0.625, 'rewards/margins': 0.23141425848007202, 'logps/chosen': -383.7161865234375, 'logps/rejected': -314.1759338378906, 'logits/chosen': 4.323853969573975, 'logits/rejected': 3.2117815017700195, 'epoch': 0.02}
# {'loss': 0.664, 'grad_norm': 76.62689208984375, 'learning_rate': 4.7e-05, 'rewards/chosen': -0.6749621033668518, 'rewards/rejected': -0.9039751291275024, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.22901295125484467, 'logps/chosen': -397.6385498046875, 'logps/rejected': -374.51055908203125, 'logits/chosen': 3.735689878463745, 'logits/rejected': 4.1204681396484375, 'epoch': 0.02}
# {'loss': 0.5153, 'grad_norm': 76.53252410888672, 'learning_rate': 4.75e-05, 'rewards/chosen': -0.4810531735420227, 'rewards/rejected': -1.0075340270996094, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5264809131622314, 'logps/chosen': -487.4775085449219, 'logps/rejected': -370.2368469238281, 'logits/chosen': 2.4078714847564697, 'logits/rejected': 2.608168840408325, 'epoch': 0.02}
# {'loss': 0.5843, 'grad_norm': 89.26786804199219, 'learning_rate': 4.8e-05, 'rewards/chosen': -0.5927323698997498, 'rewards/rejected': -1.1579501628875732, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.5652178525924683, 'logps/chosen': -459.59674072265625, 'logps/rejected': -577.461669921875, 'logits/chosen': 3.352513313293457, 'logits/rejected': 3.657254934310913, 'epoch': 0.02}
# {'loss': 0.7588, 'grad_norm': 67.53067016601562, 'learning_rate': 4.85e-05, 'rewards/chosen': -0.6897354125976562, 'rewards/rejected': -0.66398024559021, 'rewards/accuracies': 0.5, 'rewards/margins': -0.025755152106285095, 'logps/chosen': -381.22991943359375, 'logps/rejected': -252.85891723632812, 'logits/chosen': 3.2409353256225586, 'logits/rejected': 3.4674057960510254, 'epoch': 0.02}
# {'loss': 0.5235, 'grad_norm': 64.04208374023438, 'learning_rate': 4.9e-05, 'rewards/chosen': -0.39471134543418884, 'rewards/rejected': -0.8650037050247192, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.47029227018356323, 'logps/chosen': -431.9757080078125, 'logps/rejected': -267.82257080078125, 'logits/chosen': 2.352721691131592, 'logits/rejected': 3.5337471961975098, 'epoch': 0.03}
# {'loss': 0.5769, 'grad_norm': 80.98358917236328, 'learning_rate': 4.9500000000000004e-05, 'rewards/chosen': -0.45600882172584534, 'rewards/rejected': -1.0726587772369385, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.6166499853134155, 'logps/chosen': -667.453369140625, 'logps/rejected': -705.5763549804688, 'logits/chosen': 2.8582699298858643, 'logits/rejected': 3.789044141769409, 'epoch': 0.03}
# {'loss': 0.5741, 'grad_norm': 63.30891418457031, 'learning_rate': 5e-05, 'rewards/chosen': -0.5988349318504333, 'rewards/rejected': -0.9402332901954651, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3413983881473541, 'logps/chosen': -330.6367492675781, 'logps/rejected': -237.15235900878906, 'logits/chosen': 2.670198440551758, 'logits/rejected': 1.6050896644592285, 'epoch': 0.03}
# {'loss': 0.5559, 'grad_norm': 64.11656951904297, 'learning_rate': 4.998766400914329e-05, 'rewards/chosen': -0.7261903882026672, 'rewards/rejected': -1.1161081790924072, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3899177312850952, 'logps/chosen': -450.8056640625, 'logps/rejected': -374.71466064453125, 'logits/chosen': 3.167264223098755, 'logits/rejected': 3.6512913703918457, 'epoch': 0.03}
# {'loss': 0.7983, 'grad_norm': 101.8381576538086, 'learning_rate': 4.995066821070679e-05, 'rewards/chosen': -1.2341209650039673, 'rewards/rejected': -1.1994632482528687, 'rewards/accuracies': 0.5, 'rewards/margins': -0.034657783806324005, 'logps/chosen': -637.1887817382812, 'logps/rejected': -525.9739990234375, 'logits/chosen': 3.199306011199951, 'logits/rejected': 3.5404913425445557, 'epoch': 0.03}
# {'loss': 0.4042, 'grad_norm': 54.78422546386719, 'learning_rate': 4.9889049115077005e-05, 'rewards/chosen': -0.46485447883605957, 'rewards/rejected': -1.3641643524169922, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.8993099331855774, 'logps/chosen': -526.0516357421875, 'logps/rejected': -438.7064208984375, 'logits/chosen': 2.723580837249756, 'logits/rejected': 2.959117889404297, 'epoch': 0.03}
# {'loss': 0.6956, 'grad_norm': 76.76716613769531, 'learning_rate': 4.980286753286195e-05, 'rewards/chosen': -0.6599918603897095, 'rewards/rejected': -0.7372196912765503, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.07722785323858261, 'logps/chosen': -456.3335266113281, 'logps/rejected': -320.4922790527344, 'logits/chosen': 1.930893898010254, 'logits/rejected': 2.72776460647583, 'epoch': 0.03}
# {'loss': 0.8421, 'grad_norm': 89.12865447998047, 'learning_rate': 4.9692208514878444e-05, 'rewards/chosen': -1.1291179656982422, 'rewards/rejected': -1.0245325565338135, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.10458528995513916, 'logps/chosen': -336.4559020996094, 'logps/rejected': -275.401123046875, 'logits/chosen': 4.517026901245117, 'logits/rejected': 3.0482311248779297, 'epoch': 0.03}
# {'loss': 0.6491, 'grad_norm': 79.68854522705078, 'learning_rate': 4.9557181268217227e-05, 'rewards/chosen': -0.7216363549232483, 'rewards/rejected': -1.0896872282028198, 'rewards/accuracies': 0.5, 'rewards/margins': 0.3680509626865387, 'logps/chosen': -467.8008728027344, 'logps/rejected': -323.4576721191406, 'logits/chosen': 2.7159433364868164, 'logits/rejected': 3.234611749649048, 'epoch': 0.03}
# {'loss': 0.5627, 'grad_norm': 68.93115234375, 'learning_rate': 4.939791904846869e-05, 'rewards/chosen': -0.591702938079834, 'rewards/rejected': -1.3913600444793701, 'rewards/accuracies': 0.75, 'rewards/margins': 0.7996570467948914, 'logps/chosen': -356.59674072265625, 'logps/rejected': -397.5023193359375, 'logits/chosen': 3.8574020862579346, 'logits/rejected': 3.374978542327881, 'epoch': 0.03}
# {'loss': 0.6008, 'grad_norm': 84.62940216064453, 'learning_rate': 4.9214579028215776e-05, 'rewards/chosen': -1.20941162109375, 'rewards/rejected': -1.5044411420822144, 'rewards/accuracies': 0.75, 'rewards/margins': 0.29502958059310913, 'logps/chosen': -565.951416015625, 'logps/rejected': -435.1461486816406, 'logits/chosen': 2.4898033142089844, 'logits/rejected': 2.4910802841186523, 'epoch': 0.03}
# {'loss': 0.6242, 'grad_norm': 77.41275024414062, 'learning_rate': 4.900734214192358e-05, 'rewards/chosen': -0.8226505517959595, 'rewards/rejected': -1.2576611042022705, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.4350106120109558, 'logps/chosen': -386.964599609375, 'logps/rejected': -382.7132873535156, 'logits/chosen': 1.992618441581726, 'logits/rejected': 2.312711477279663, 'epoch': 0.03}
# {'loss': 0.5695, 'grad_norm': 68.68437957763672, 'learning_rate': 4.877641290737884e-05, 'rewards/chosen': -0.8830019235610962, 'rewards/rejected': -1.3811981678009033, 'rewards/accuracies': 0.75, 'rewards/margins': 0.49819642305374146, 'logps/chosen': -470.14599609375, 'logps/rejected': -465.7132263183594, 'logits/chosen': 1.5870712995529175, 'logits/rejected': 2.3566486835479736, 'epoch': 0.03}
# {'loss': 0.6939, 'grad_norm': 99.83089447021484, 'learning_rate': 4.852201922385564e-05, 'rewards/chosen': -0.8200038075447083, 'rewards/rejected': -1.2636821269989014, 'rewards/accuracies': 0.625, 'rewards/margins': 0.4436783492565155, 'logps/chosen': -556.709716796875, 'logps/rejected': -439.4492492675781, 'logits/chosen': 2.697470188140869, 'logits/rejected': 2.327958106994629, 'epoch': 0.03}
# {'loss': 0.6641, 'grad_norm': 74.72027587890625, 'learning_rate': 4.8244412147206284e-05, 'rewards/chosen': -0.8270342946052551, 'rewards/rejected': -1.1829519271850586, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3559176027774811, 'logps/chosen': -486.70880126953125, 'logps/rejected': -405.1001892089844, 'logits/chosen': 2.1541285514831543, 'logits/rejected': 2.3656249046325684, 'epoch': 0.03}
# ...
# {'loss': 0.6612, 'grad_norm': 96.51509857177734, 'learning_rate': 1.2956158147457115e-05, 'rewards/chosen': -1.3434866666793823, 'rewards/rejected': -1.6814358234405518, 'rewards/accuracies': 0.625, 'rewards/margins': 0.33794909715652466, 'logps/chosen': -626.5802612304688, 'logps/rejected': -609.850830078125, 'logits/chosen': 3.6655609607696533, 'logits/rejected': 3.570819854736328, 'epoch': 0.04}
# {'loss': 0.8642, 'grad_norm': 101.97940826416016, 'learning_rate': 1.2273964606240718e-05, 'rewards/chosen': -1.73334801197052, 'rewards/rejected': -1.6370384693145752, 'rewards/accuracies': 0.5, 'rewards/margins': -0.09630955755710602, 'logps/chosen': -475.447509765625, 'logps/rejected': -441.0943603515625, 'logits/chosen': 2.1342761516571045, 'logits/rejected': 3.108541250228882, 'epoch': 0.04}
# {'loss': 0.7162, 'grad_norm': 97.58856201171875, 'learning_rate': 1.1604330125525079e-05, 'rewards/chosen': -0.9389013051986694, 'rewards/rejected': -1.184065580368042, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.24516424536705017, 'logps/chosen': -446.96514892578125, 'logps/rejected': -410.22186279296875, 'logits/chosen': 2.7363364696502686, 'logits/rejected': 3.3723976612091064, 'epoch': 0.04}
# {'loss': 0.971, 'grad_norm': 102.16847229003906, 'learning_rate': 1.0947915553696742e-05, 'rewards/chosen': -1.6274491548538208, 'rewards/rejected': -1.3356674909591675, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.29178181290626526, 'logps/chosen': -421.9140930175781, 'logps/rejected': -358.8350830078125, 'logits/chosen': 4.1628499031066895, 'logits/rejected': 3.0106611251831055, 'epoch': 0.04}
# {'loss': 0.503, 'grad_norm': 82.80419158935547, 'learning_rate': 1.0305368692688174e-05, 'rewards/chosen': -1.1552000045776367, 'rewards/rejected': -2.152590751647949, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.9973907470703125, 'logps/chosen': -307.78106689453125, 'logps/rejected': -429.1602478027344, 'logits/chosen': 3.361095428466797, 'logits/rejected': 4.333255767822266, 'epoch': 0.04}
# {'loss': 0.5639, 'grad_norm': 75.23948669433594, 'learning_rate': 9.677323658675594e-06, 'rewards/chosen': -1.0382293462753296, 'rewards/rejected': -1.4969148635864258, 'rewards/accuracies': 0.625, 'rewards/margins': 0.4586855471134186, 'logps/chosen': -539.0936279296875, 'logps/rejected': -471.1349182128906, 'logits/chosen': 3.053058385848999, 'logits/rejected': 2.4909698963165283, 'epoch': 0.04}
# {'loss': 0.9677, 'grad_norm': 108.57426452636719, 'learning_rate': 9.064400256282757e-06, 'rewards/chosen': -1.0990957021713257, 'rewards/rejected': -0.9279133677482605, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.17118233442306519, 'logps/chosen': -312.7669677734375, 'logps/rejected': -385.54449462890625, 'logits/chosen': 2.794469118118286, 'logits/rejected': 4.079151153564453, 'epoch': 0.04}
# {'loss': 0.7191, 'grad_norm': 86.07710266113281, 'learning_rate': 8.467203366908707e-06, 'rewards/chosen': -1.2879664897918701, 'rewards/rejected': -1.6892223358154297, 'rewards/accuracies': 0.625, 'rewards/margins': 0.40125563740730286, 'logps/chosen': -514.8207397460938, 'logps/rejected': -425.537109375, 'logits/chosen': 4.640356540679932, 'logits/rejected': 4.4182868003845215, 'epoch': 0.04}
# {'loss': 0.6882, 'grad_norm': 72.76337432861328, 'learning_rate': 7.886322351782783e-06, 'rewards/chosen': -0.9977889060974121, 'rewards/rejected': -1.362886667251587, 'rewards/accuracies': 0.625, 'rewards/margins': 0.36509770154953003, 'logps/chosen': -384.9964904785156, 'logps/rejected': -371.75054931640625, 'logits/chosen': 2.438009023666382, 'logits/rejected': 1.1836421489715576, 'epoch': 0.04}
# {'loss': 0.7522, 'grad_norm': 87.38998413085938, 'learning_rate': 7.3223304703363135e-06, 'rewards/chosen': -1.3943848609924316, 'rewards/rejected': -1.5989670753479004, 'rewards/accuracies': 0.625, 'rewards/margins': 0.20458224415779114, 'logps/chosen': -292.2099609375, 'logps/rejected': -275.727783203125, 'logits/chosen': 3.6385483741760254, 'logits/rejected': 3.4764575958251953, 'epoch': 0.05}
# {'loss': 0.5107, 'grad_norm': 57.404964447021484, 'learning_rate': 6.775784314464717e-06, 'rewards/chosen': -0.8989890217781067, 'rewards/rejected': -1.4820314645767212, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.5830425024032593, 'logps/chosen': -340.79754638671875, 'logps/rejected': -285.6732177734375, 'logits/chosen': 3.7341058254241943, 'logits/rejected': 3.833293914794922, 'epoch': 0.05}
# {'loss': 0.7221, 'grad_norm': 107.50656127929688, 'learning_rate': 6.247223259238511e-06, 'rewards/chosen': -1.0296876430511475, 'rewards/rejected': -1.5936381816864014, 'rewards/accuracies': 0.625, 'rewards/margins': 0.5639505982398987, 'logps/chosen': -496.945068359375, 'logps/rejected': -473.3502197265625, 'logits/chosen': 1.4903082847595215, 'logits/rejected': 1.6514497995376587, 'epoch': 0.05}
# {'loss': 0.3376, 'grad_norm': 53.724666595458984, 'learning_rate': 5.737168930605272e-06, 'rewards/chosen': -0.579434335231781, 'rewards/rejected': -2.005319595336914, 'rewards/accuracies': 0.75, 'rewards/margins': 1.4258852005004883, 'logps/chosen': -440.8480224609375, 'logps/rejected': -664.822265625, 'logits/chosen': 3.4323325157165527, 'logits/rejected': 3.792081594467163, 'epoch': 0.05}
# {'loss': 0.8145, 'grad_norm': 114.9795150756836, 'learning_rate': 5.24612469060774e-06, 'rewards/chosen': -1.0122871398925781, 'rewards/rejected': -1.0871288776397705, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.07484181225299835, 'logps/chosen': -342.392333984375, 'logps/rejected': -242.20755004882812, 'logits/chosen': 4.782022476196289, 'logits/rejected': 4.403435230255127, 'epoch': 0.05}
# {'loss': 0.534, 'grad_norm': 61.625732421875, 'learning_rate': 4.7745751406263165e-06, 'rewards/chosen': -1.0976004600524902, 'rewards/rejected': -1.7682771682739258, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.670676589012146, 'logps/chosen': -451.43621826171875, 'logps/rejected': -281.72357177734375, 'logits/chosen': 3.5040674209594727, 'logits/rejected': 2.6966655254364014, 'epoch': 0.05}
# {'loss': 0.5005, 'grad_norm': 63.590797424316406, 'learning_rate': 4.322985643135952e-06, 'rewards/chosen': -1.0119609832763672, 'rewards/rejected': -1.7202917337417603, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.7083307504653931, 'logps/chosen': -597.6585083007812, 'logps/rejected': -450.57318115234375, 'logits/chosen': 3.777312755584717, 'logits/rejected': 3.527179479598999, 'epoch': 0.05}
# {'loss': 0.5788, 'grad_norm': 53.5258903503418, 'learning_rate': 3.891801862449629e-06, 'rewards/chosen': -0.9931073188781738, 'rewards/rejected': -1.5281078815460205, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5350005626678467, 'logps/chosen': -338.2425537109375, 'logps/rejected': -286.65960693359375, 'logits/chosen': 4.018305778503418, 'logits/rejected': 3.931887626647949, 'epoch': 0.05}
# {'loss': 0.6349, 'grad_norm': 83.23916625976562, 'learning_rate': 3.4814493249014116e-06, 'rewards/chosen': -1.2469170093536377, 'rewards/rejected': -1.5558156967163086, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.3088987171649933, 'logps/chosen': -519.8538818359375, 'logps/rejected': -359.50927734375, 'logits/chosen': 2.999412775039673, 'logits/rejected': 2.9207375049591064, 'epoch': 0.05}
# {'loss': 0.8568, 'grad_norm': 106.77947998046875, 'learning_rate': 3.092332998903416e-06, 'rewards/chosen': -1.4246656894683838, 'rewards/rejected': -1.524398684501648, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.09973293542861938, 'logps/chosen': -430.52984619140625, 'logps/rejected': -440.6264953613281, 'logits/chosen': 3.47031831741333, 'logits/rejected': 4.08922815322876, 'epoch': 0.05}
# {'loss': 0.5205, 'grad_norm': 60.41245651245117, 'learning_rate': 2.7248368952908053e-06, 'rewards/chosen': -0.8305609822273254, 'rewards/rejected': -1.5370972156524658, 'rewards/accuracies': 0.75, 'rewards/margins': 0.7065361738204956, 'logps/chosen': -339.0815734863281, 'logps/rejected': -441.96478271484375, 'logits/chosen': 2.491584062576294, 'logits/rejected': 3.222261667251587, 'epoch': 0.05}
# {'loss': 0.5745, 'grad_norm': 61.25863265991211, 'learning_rate': 2.379323688349516e-06, 'rewards/chosen': -1.1562868356704712, 'rewards/rejected': -1.7343984842300415, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5781117677688599, 'logps/chosen': -459.35003662109375, 'logps/rejected': -443.6688537597656, 'logits/chosen': 3.74257755279541, 'logits/rejected': 4.116559028625488, 'epoch': 0.05}
# {'loss': 0.7866, 'grad_norm': 78.30425262451172, 'learning_rate': 2.0561343579004715e-06, 'rewards/chosen': -1.1648213863372803, 'rewards/rejected': -1.434395670890808, 'rewards/accuracies': 0.5, 'rewards/margins': 0.2695743441581726, 'logps/chosen': -385.89544677734375, 'logps/rejected': -335.345947265625, 'logits/chosen': 3.4160892963409424, 'logits/rejected': 3.1702935695648193, 'epoch': 0.05}
# {'loss': 0.4767, 'grad_norm': 58.88700485229492, 'learning_rate': 1.7555878527937164e-06, 'rewards/chosen': -0.7210851311683655, 'rewards/rejected': -1.4541051387786865, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.733020007610321, 'logps/chosen': -288.47967529296875, 'logps/rejected': -349.9775390625, 'logits/chosen': 2.749300718307495, 'logits/rejected': 2.852566719055176, 'epoch': 0.05}
# {'loss': 0.7741, 'grad_norm': 90.11611938476562, 'learning_rate': 1.4779807761443636e-06, 'rewards/chosen': -1.1898921728134155, 'rewards/rejected': -1.2695409059524536, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.07964888215065002, 'logps/chosen': -420.5401611328125, 'logps/rejected': -460.94049072265625, 'logits/chosen': 1.048879623413086, 'logits/rejected': 2.7808961868286133, 'epoch': 0.05}
# {'loss': 0.516, 'grad_norm': 67.40521240234375, 'learning_rate': 1.2235870926211619e-06, 'rewards/chosen': -0.8284075260162354, 'rewards/rejected': -1.3397570848464966, 'rewards/accuracies': 0.625, 'rewards/margins': 0.5113494992256165, 'logps/chosen': -369.1314697265625, 'logps/rejected': -381.07843017578125, 'logits/chosen': 2.7313172817230225, 'logits/rejected': 2.2113559246063232, 'epoch': 0.05}
# {'loss': 0.8332, 'grad_norm': 91.75272369384766, 'learning_rate': 9.926578580764234e-07, 'rewards/chosen': -1.2705878019332886, 'rewards/rejected': -1.3010401725769043, 'rewards/accuracies': 0.625, 'rewards/margins': 0.03045237809419632, 'logps/chosen': -398.4837951660156, 'logps/rejected': -356.0270080566406, 'logits/chosen': 3.528782844543457, 'logits/rejected': 4.046397686004639, 'epoch': 0.05}
# {'loss': 0.6547, 'grad_norm': 68.42618560791016, 'learning_rate': 7.854209717842231e-07, 'rewards/chosen': -0.8350329399108887, 'rewards/rejected': -1.320347785949707, 'rewards/accuracies': 0.625, 'rewards/margins': 0.4853147864341736, 'logps/chosen': -320.2624206542969, 'logps/rejected': -317.8100891113281, 'logits/chosen': 2.8422608375549316, 'logits/rejected': 2.275508403778076, 'epoch': 0.05}
# {'loss': 0.6744, 'grad_norm': 80.44812774658203, 'learning_rate': 6.020809515313142e-07, 'rewards/chosen': -1.225900411605835, 'rewards/rejected': -1.4252697229385376, 'rewards/accuracies': 0.5, 'rewards/margins': 0.19936931133270264, 'logps/chosen': -428.7957763671875, 'logps/rejected': -338.12774658203125, 'logits/chosen': 2.571655511856079, 'logits/rejected': 2.566603422164917, 'epoch': 0.05}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Train the model
# ----> 2 trainer.train()
#       4 # Save the model
#       5 trainer.save_model(f"./{finetune_name}")
#
# File ~/src/smol-course/.venv/lib/python3.11/site-packages/transformers/trainer.py:2123, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2121         hf_hub_utils.enable_progress_bars()
#    2122 else:
# -> 2123     return inner_training_loop(
#    2124         args=args,
#    2125         resume_from_checkpoint=resume_from_checkpoint,
#    2126         trial=trial,
#    2127         ignore_keys_for_eval=ignore_keys_for_eval,
#    2128     )
#
# File ~/src/smol-course/.venv/lib/python3.11/site-packages/transformers/trainer.py:2481, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2475 context = (
#    2476     functools.partial(self.accelerator.no_sync, model=model)
#    2477     if i != len(batch_samples) - 1
#    2478     else contextlib.nullcontext
#    2479 )
#    2480 with context():
# -> 2481     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2483 if (
#    2484     args.logging_nan_inf_filter
#    2485     and not is_torch_xla_available()
#    2486     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2487 ):
#    2488     # if loss is nan or inf simply add the average of previous logged losses
#    2489     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/src/smol-course/.venv/lib/python3.11/site-packages/transformers/trainer.py:3579, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    3576     return loss_mb.reduce_mean().detach().to(self.args.device)
#    3578 with self.compute_loss_context_manager():
# -> 3579     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    3581 del inputs
#    3582 if (
#    3583     self.args.torch_empty_cache_steps is not None
#    3584     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    3585 ):
#
# File ~/src/smol-course/.venv/lib/python3.11/site-packages/trl/trainer/dpo_trainer.py:1371, in DPOTrainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    1369 compute_loss_context_manager = amp.autocast("cuda") if self._peft_has_been_casted_to_bf16 else nullcontext()
#    1370 with compute_loss_context_manager:
# -> 1371     loss, metrics = self.get_batch_loss_metrics(model, inputs, train_eval="train")
#    1373 # Make sure to move the loss to the device the original accumulating loss is at back in the `Trainer` class:
#    1374 loss = loss.to(self.args.device)
#
# File ~/src/smol-course/.venv/lib/python3.11/site-packages/trl/trainer/dpo_trainer.py:1330, in DPOTrainer.get_batch_loss_metrics(self, model, batch, train_eval)
#    1328     ref_rejected_logps = batch["ref_rejected_logps"]
#    1329 else:
# -> 1330     ref_chosen_logps, ref_rejected_logps = self.compute_ref_log_probs(batch)
#    1332 losses, chosen_rewards, rejected_rewards = self.dpo_loss(
#    1333     model_output["chosen_logps"], model_output["rejected_logps"], ref_chosen_logps, ref_rejected_logps
#    1334 )
#    1335 reward_accuracies = (chosen_rewards > rejected_rewards).float()
#
# File ~/src/smol-course/.venv/lib/python3.11/site-packages/trl/trainer/dpo_trainer.py:950, in DPOTrainer.compute_ref_log_probs(self, batch)
#     948             ref_model_output = self.concatenated_forward(self.model, batch)
#     949     else:
# --> 950         ref_model_output = self.concatenated_forward(self.ref_model, batch)
#     951 return ref_model_output["chosen_logps"], ref_model_output["rejected_logps"]
#
# File ~/src/smol-course/.venv/lib/python3.11/site-packages/trl/trainer/dpo_trainer.py:1274, in DPOTrainer.concatenated_forward(self, model, batch)
#    1272 # Compute the log probabilities of the labels
#    1273 labels[~loss_mask] = 0  # dummy token; we'll ignore the losses on these tokens later
# -> 1274 per_token_logps = torch.gather(logits.log_softmax(-1), dim=2, index=labels.unsqueeze(2)).squeeze(2)
#    1275 per_token_logps[~loss_mask] = 0
#    1276 all_logps = per_token_logps.sum(-1)
#
# RuntimeError: MPS backend out of memory (MPS allocated: 26.54 GB, other allocations: 53.68 GB, max allowed: 81.60 GB). Tried to allocate 2.20 GB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).

# %% [markdown]
# ## 💐 You're done!
#
# This notebook provided a step-by-step guide to fine-tuning the `HuggingFaceTB/SmolLM2-135M` model using the `DPOTrainer`. By following these steps, you can adapt the model to perform specific tasks more effectively. If you want to carry on working on this course, here are steps you could try out:
#
# - Try this notebook on a harder difficulty
# - Review a colleagues PR
# - Improve the course material via an Issue or PR.
